# %%
# %matplotlib inline

# %% [markdown]
# Training a Classifier
# =====================

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
from PIL import Image

# %% [markdown]
# The output of torchvision datasets are PILImage images of range [0, 1].
# We transform them to Tensors of normalized range [-1, 1].
# <div class="alert alert-info"><h4>Note</h4><p>If running on Windows and you get a BrokenPipeError, try setting
#     the num_worker of torch.utils.data.DataLoader() to 0.</p></div>

# %%
# Set up dataset and classes

transform = transforms.Compose(
    [transforms.Resize((400,400), interpolation=Image.NEAREST), 
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

data_dir = '../cub_birds_data/'

dataSet = torchvision.datasets.ImageFolder(root=data_dir+'images', transform=transform)

trainloader = torch.utils.data.DataLoader(dataSet, batch_size=16,
                                          shuffle=True, num_workers=2)

f = open(data_dir + "lists/classes.txt", "r")
classes = []
for x in f:
  classes.append(x[4:-1])

# %% [markdown]
# ### Let us show some of the training images, for fun.

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
# Show example image with label

im1, class1 = dataSet[39]
print('class1:', class1, ' ', classes[class1])
imshow(im1)
# Out:
# class1: 1   Laysan_Albatross

# %% [markdown]
# ### 3. Define a Loss function and optimizer
# Let's use a Classification Cross-Entropy loss and SGD with momentum.

# %%
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

# use resnet18 network and change the last layer to output 200 numbers
# for our 200 classes

net = models.resnet18()
net.fc = torch.nn.Linear(512, 200)
net = nn.Sequential(
    net,
    nn.Softmax(1)
)

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# ### 4. Train the network
#
# This is when things start to get interesting.
# We simply have to loop over our data iterator, and feed the inputs to the
# network and optimize.

# %%
# same uncertainty measure as seen in that medium post
# uncertainty = most confident - least confident

def get_active_batches(trainloader, net, num_batches=1): 
    flag = True
    #data_active = None
    #labels_active = None
    #uncertain_ratio = None
    act_dict = {}
    count_key = 0

    for i, data in enumerate(trainloader, 0):
        inputs, labels = [d.to(device) for d in data]

        outputs = net(inputs)
        
        outputs_cpu = outputs.cpu()
        outputs_np = outputs_cpu.detach().numpy()
        
        max_batch = 0
        min_batch = 0
        for out in outputs_np:
            max_batch += max(out)
            min_batch += min(out)
        
        if len(act_dict.keys()) < num_batches:
            act_dict[count_key] = [max_batch - min_batch, inputs, labels]
            count_key += 1
        else:
            for key in act_dict:
                if act_dict[key][0] < max_batch - min_batch:
                    act_dict[key] = [max_batch - min_batch, inputs, labels]
    
    print('largest uncertainties', [act_dict[key][0] for key in act_dict])
    active_data = []
    active_labels = []
    for key in act_dict:
        active_data.append(act_dict[key][1])
        active_labels.append(act_dict[key][2])
    
    return active_data, active_labels

def train(net, inputs, labels):
    assert len(inputs) == len(labels)
    for i in range(len(inputs)):
        # zero the parameter gradients
        optimizer.zero_grad()

        # forward + backward + optimize
        outputs = net(inputs[i])
        loss = criterion(outputs, labels[i])
        loss.backward()
        optimizer.step()
        print('loss:', loss.item())
        return loss.item()
    
loss = 1
training_epochs = 2
num_epoch = 0
while loss > 0.2 and num_epoch < training_epochs:
    data_act, labels_act = get_active_batches(trainloader, net, num_batches=5)
    loss = train(net, data_act, labels_act)
    num_epoch += 1


print('Finished Training')
# Out:
# largest uncertainties [0.36762537344475277, 0.36762537344475277, 0.36762537344475277, 0.36762537344475277, 0.36762537344475277]
# loss: 5.2982378005981445
# largest uncertainties [0.37250534044142114, 0.37250534044142114, 0.37250534044142114, 0.37250534044142114, 0.37250534044142114]
# loss: 5.298527240753174
# Finished Training

# %%
def default_training(net, trainloader, num_epochs):
    for epoch in range(num_epochs):  # loop over the dataset multiple times

        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # get the inputs; data is a list of [inputs, labels]
            #inputs, labels = data.to(device)
            inputs, labels = [d.to(device) for d in data]

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            if i % 2000 == 1999:    # print every 2000 mini-batches
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 2000))
                running_loss = 0.0

# %% [markdown]
# Let's quickly save our trained model:

# %%
PATH = './cub_birds_net.pth'
torch.save(net.state_dict(), PATH)

# %% [markdown]
# ### 5. Test the network on the test data

# %%
# Show example images

dataiter = iter(trainloader)
images, labels = dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(16)))
# Out:
# GroundTruth:  Hooded_Warbler Cape_Glossy_Starling Rufous_Hummingbird Scissor_tailed_Flycatcher White_breasted_Nuthatch Heermann_Gull Brandt_Cormorant Louisiana_Waterthrush Song_Sparrow Prairie_Warbler Red_headed_Woodpecker Acadian_Flycatcher White_breasted_Nuthatch California_Gull Ringed_Kingfisher European_Goldfinch

# %% [markdown]
# Next, let's load back in our saved model (note: saving and re-loading the model
# wasn't necessary here, we only did it to illustrate how to do so):

# %%
#net = Net()
#net = models.resnet18()
#net.load_state_dict(torch.load(PATH))

# %% [markdown]
# Okay, now let us see what the neural network thinks these examples above are:

# %%
# Example outputs

outputs = net(images.to(device))
outputs.shape

print('Ground Truth Labels:')
[print(classes[label]) for label in labels]
print('\nOutput Labels:')
[print(classes[list(out).index(max(out))]) for out in outputs]

images_gpu = images.to(device)
net(images_gpu).shape
# Out:
# Ground Truth Labels:
# Hooded_Warbler
# Cape_Glossy_Starling
# Rufous_Hummingbird
# Scissor_tailed_Flycatcher
# White_breasted_Nuthatch
# Heermann_Gull
# Brandt_Cormorant
# Louisiana_Waterthrush
# Song_Sparrow
# Prairie_Warbler
# Red_headed_Woodpecker
# Acadian_Flycatcher
# White_breasted_Nuthatch
# California_Gull
# Ringed_Kingfisher
# European_Goldfinch
#
# Output Labels:
# Orange_crowned_Warbler
# Orange_crowned_Warbler
# Orange_crowned_Warbler
# Orange_crowned_Warbler
# Orange_crowned_Warbler
# Orange_crowned_Warbler
# Orange_crowned_Warbler
# Orange_crowned_Warbler
# Orange_crowned_Warbler
# Orange_crowned_Warbler
# Orange_crowned_Warbler
# Orange_crowned_Warbler
# Orange_crowned_Warbler
# Orange_crowned_Warbler
# Orange_crowned_Warbler
# Orange_crowned_Warbler
# torch.Size([16, 200])

# %% [markdown]
# ### Outputs
# The outputs are energies for the 200 classes.
# The higher the energy for a class, the more the network
# thinks that the image is of the particular class.
# So, let's get the index of the highest energy.
# Let us look at how the network performs on the whole dataset.

# %%
correct = 0
total = 0
with torch.no_grad():
    # dataiter = iter(trainloader)
    for data in trainloader:
        images, labels = [d.to(device) for d in data] # data
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the %d test images: %d %%' % (len(trainloader),  
    100 * correct / total))
# Out:
# Accuracy of the network on the 378 test images: 0 %

# %% [markdown]
# That looks way better than chance, which is 10% accuracy (randomly picking
# a class out of 10 classes).
# Seems like the network learnt something.
#
# Hmmm, what are the classes that performed well, and the classes that did
# not perform well:

# %%
class_correct = list(0. for i in range(200))
class_total = list(0. for i in range(200))

count = 0
with torch.no_grad():
    for data in trainloader:
        count += 1
        if count == len(trainloader):
            break
        images, labels = [d.to(device) for d in data] # data
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(16):
            label = labels[i]
            #print('label', label.item(), label)
            #print('c[i]', c[i])
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(len(classes)):
    print('Accuracy of %5s : %4d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
