# %%
# %matplotlib inline

# %% [markdown]
# Training a Classifier
# =====================

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torchvision.models as models
from PIL import Image

# %% [markdown]
# The output of torchvision datasets are PILImage images of range [0, 1].
# We transform them to Tensors of normalized range [-1, 1].
# <div class="alert alert-info"><h4>Note</h4><p>If running on Windows and you get a BrokenPipeError, try setting
#     the num_worker of torch.utils.data.DataLoader() to 0.</p></div>

# %%
# Set up dataset and classes

transform = transforms.Compose(
    [transforms.Resize((400,400), interpolation=Image.NEAREST), 
     transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

data_dir = '../cub_birds_data/'

dataSet = torchvision.datasets.ImageFolder(root=data_dir+'images', transform=transform)

trainloader = torch.utils.data.DataLoader(dataSet, batch_size=16,
                                          shuffle=True, num_workers=2)

f = open(data_dir + "lists/classes.txt", "r")
classes = []
for x in f:
  classes.append(x[4:-1])

# %% [markdown]
# ### Let us show some of the training images, for fun.

# %%
import matplotlib.pyplot as plt
import numpy as np

# functions to show an image
def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
# Show example image with label

im1, class1 = dataSet[39]
print('class1:', class1, ' ', classes[class1])
imshow(im1)
# Out:
# class1: 1   Laysan_Albatross

# %%
# use resnet18 network and change the last layer to output 200 numbers
# for our 200 classes

net = models.resnet18()
net.fc = torch.nn.Linear(512, 200)
net = nn.Sequential(
    net,
    nn.Softmax(1)
)

# %% [markdown]
# ### 3. Define a Loss function and optimizer
# Let's use a Classification Cross-Entropy loss and SGD with momentum.

# %%
import torch.optim as optim
import torch.nn as nn
import torch.nn.functional as F

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
net.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# ### 4. Train the network
#
# This is when things start to get interesting.
# We simply have to loop over our data iterator, and feed the inputs to the
# network and optimize.

# %%
input_cpu = inputs.cpu()
imshow(input_cpu[0])
labels_cpu = labels.cpu()
output = net(inputs)
output_cpu = output.cpu()
output_np = output_cpu.detach().numpy()[0]
print(max(output_np), ' ', min(output_np))
plt.hist(output_np)
# Out:
# 0.013404244   0.0016021037
# (array([32., 47., 43., 33., 17.,  8.,  9.,  6.,  1.,  4.]),
#  array([0.0016021 , 0.00278232, 0.00396253, 0.00514275, 0.00632296,
#         0.00750317, 0.00868339, 0.0098636 , 0.01104382, 0.01222403,
#         0.01340424], dtype=float32),
#  <a list of 10 Patch objects>)

# %%
# same uncertainty measure as seen in that medium post
# uncertainty = most confident - least confident

def get_active_batches(trainloader, net): 
    flag = True
    data_active = None
    labels_active = None
    uncertain_ratio = None

    for i, data in enumerate(trainloader, 0):
        inputs, labels = [d.to(device) for d in data]

        outputs = net(inputs)
        
        outputs_cpu = outputs.cpu()
        outputs_np = outputs_cpu.detach().numpy()
        
        max_batch = 0
        min_batch = 0
        for out in outputs_np:
            max_batch += max(out)
            min_batch += min(out)
        
        if uncertain_ratio is None or uncertain_ratio < (max_batch - min_batch):
            uncertain_ratio = (max_batch - min_batch)
            data_active = inputs
            labels_active = labels
    
    print('largest uncertainty:', uncertain_ratio)
    return data_active, labels_active

def train(net, inputs, labels):
     # zero the parameter gradients
    optimizer.zero_grad()

    # forward + backward + optimize
    outputs = net(inputs)
    loss = criterion(outputs, labels)
    loss.backward()
    optimizer.step()
    print('loss:', loss.item())
    return loss.item()
    
loss = 1
while loss > 0.2:
    data_act, labels_act = get_active_batches(trainloader, net)
    loss = train(net, data_act, labels_act)


print('Finished Training')

# %%
def default_training(net, trainloader, num_epochs)
    for epoch in range(num_epochs):  # loop over the dataset multiple times

        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # get the inputs; data is a list of [inputs, labels]
            #inputs, labels = data.to(device)
            inputs, labels = [d.to(device) for d in data]

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            if i % 2000 == 1999:    # print every 2000 mini-batches
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 2000))
                running_loss = 0.0

# %% [markdown]
# Let's quickly save our trained model:

# %%
PATH = './cub_birds_net.pth'
torch.save(net.state_dict(), PATH)

# %% [markdown]
# ### 5. Test the network on the test data

# %%
# Show example images

dataiter = iter(trainloader)
images, labels = dataiter.next()

# print images
imshow(torchvision.utils.make_grid(images))
print('GroundTruth: ', ' '.join('%5s' % classes[labels[j]] for j in range(16)))
# Out:
# GroundTruth:  Black_throated_Sparrow Purple_Finch Green_Violetear Western_Grebe

# %% [markdown]
# Next, let's load back in our saved model (note: saving and re-loading the model
# wasn't necessary here, we only did it to illustrate how to do so):

# %%
#net = Net()
#net = models.resnet18()
#net.load_state_dict(torch.load(PATH))

# %% [markdown]
# Okay, now let us see what the neural network thinks these examples above are:

# %%
# Example outputs

outputs = net(images.to(device))
outputs.shape

print('Ground Truth Labels:')
[print(classes[label]) for label in labels]
print('\nOutput Labels:')
[print(classes[list(out).index(max(out))]) for out in outputs]

images_gpu = images.to(device)
net(images_gpu).shape
# Out:
# Ground Truth Labels:
# Black_throated_Sparrow
# Purple_Finch
# Green_Violetear
# Western_Grebe
#
# Output Labels:
# Winter_Wren
# Nelson_Sharp_tailed_Sparrow
# Orchard_Oriole
# Western_Grebe
# torch.Size([4, 200])

# %% [markdown]
# ### Outputs
# The outputs are energies for the 200 classes.
# The higher the energy for a class, the more the network
# thinks that the image is of the particular class.
# So, let's get the index of the highest energy.
# Let us look at how the network performs on the whole dataset.

# %%
correct = 0
total = 0
with torch.no_grad():
    # dataiter = iter(trainloader)
    for data in trainloader:
        images, labels = [d.to(device) for d in data] # data
        outputs = net(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print('Accuracy of the network on the %d test images: %d %%' % (len(trainloader),  
    100 * correct / total))
# Out:
# Accuracy of the network on the 1509 test images: 3 %

# %% [markdown]
# That looks way better than chance, which is 10% accuracy (randomly picking
# a class out of 10 classes).
# Seems like the network learnt something.
#
# Hmmm, what are the classes that performed well, and the classes that did
# not perform well:

# %%
class_correct = list(0. for i in range(200))
class_total = list(0. for i in range(200))

count = 0
with torch.no_grad():
    for data in trainloader:
        count += 1
        if count == len(trainloader):
            break
        images, labels = [d.to(device) for d in data] # data
        outputs = net(images)
        _, predicted = torch.max(outputs, 1)
        c = (predicted == labels).squeeze()
        for i in range(16):
            label = labels[i]
            #print('label', label.item(), label)
            #print('c[i]', c[i])
            class_correct[label] += c[i].item()
            class_total[label] += 1


for i in range(200):
    print('Accuracy of %5s : %4d %%' % (
        classes[i], 100 * class_correct[i] / class_total[i]))
# Out:
# Accuracy of Black_footed_Albatross :    0 %
# Accuracy of Laysan_Albatross :    0 %
# Accuracy of Sooty_Albatross :    0 %
# Accuracy of Groove_billed_Ani :    0 %
# Accuracy of Crested_Auklet :    0 %
# Accuracy of Least_Auklet :    0 %
# Accuracy of Parakeet_Auklet :    0 %
# Accuracy of Rhinoceros_Auklet :    0 %
# Accuracy of Brewer_Blackbird :    0 %
# Accuracy of Red_winged_Blackbird :    3 %
# Accuracy of Rusty_Blackbird :    0 %
# Accuracy of Yellow_headed_Blackbird :    0 %
# Accuracy of Bobolink :    0 %
# Accuracy of Indigo_Bunting :    0 %
# Accuracy of Lazuli_Bunting :    0 %
# Accuracy of Painted_Bunting :    3 %
# Accuracy of Cardinal :    0 %
# Accuracy of Spotted_Catbird :    0 %
# Accuracy of Gray_Catbird :    0 %
# Accuracy of Yellow_breasted_Chat :    2 %
# Accuracy of Eastern_Towhee :    0 %
# Accuracy of Chuck_will_Widow :    0 %
# Accuracy of Brandt_Cormorant :    0 %
# Accuracy of Red_faced_Cormorant :    0 %
# Accuracy of Pelagic_Cormorant :    0 %
# Accuracy of Bronzed_Cowbird :    0 %
# Accuracy of Shiny_Cowbird :    3 %
# Accuracy of Brown_Creeper :    5 %
# Accuracy of American_Crow :    0 %
# Accuracy of Fish_Crow :    0 %
# Accuracy of Black_billed_Cuckoo :    0 %
# Accuracy of Mangrove_Cuckoo :    3 %
# Accuracy of Yellow_billed_Cuckoo :   16 %
# Accuracy of Gray_crowned_Rosy_Finch :    7 %
# Accuracy of Purple_Finch :    0 %
# Accuracy of Northern_Flicker :    0 %
# Accuracy of Acadian_Flycatcher :    0 %
# Accuracy of Great_Crested_Flycatcher :    0 %
# Accuracy of Least_Flycatcher :    0 %
# Accuracy of Olive_sided_Flycatcher :    0 %
# Accuracy of Scissor_tailed_Flycatcher :    0 %
# Accuracy of Vermilion_Flycatcher :    0 %
# Accuracy of Yellow_bellied_Flycatcher :    0 %
# Accuracy of Frigatebird :    9 %
# Accuracy of Northern_Fulmar :    7 %
# Accuracy of Gadwall :    0 %
# Accuracy of American_Goldfinch :    0 %
# Accuracy of European_Goldfinch :    0 %
# Accuracy of Boat_tailed_Grackle :    0 %
# Accuracy of Eared_Grebe :   18 %
# Accuracy of Horned_Grebe :    0 %
# Accuracy of Pied_billed_Grebe :    0 %
# Accuracy of Western_Grebe :   62 %
# Accuracy of Blue_Grosbeak :    0 %
# Accuracy of Evening_Grosbeak :    0 %
# Accuracy of Pine_Grosbeak :    0 %
# Accuracy of Rose_breasted_Grosbeak :    0 %
# Accuracy of Pigeon_Guillemot :    0 %
# Accuracy of California_Gull :    0 %
# Accuracy of Glaucous_winged_Gull :    0 %
# Accuracy of Heermann_Gull :    0 %
# Accuracy of Herring_Gull :    0 %
# Accuracy of Ivory_Gull :    0 %
# Accuracy of Ring_billed_Gull :    0 %
# Accuracy of Slaty_backed_Gull :    0 %
# Accuracy of Western_Gull :    0 %
# Accuracy of Anna_Hummingbird :    0 %
# Accuracy of Ruby_throated_Hummingbird :    0 %
# Accuracy of Rufous_Hummingbird :   29 %
# Accuracy of Green_Violetear :    0 %
# Accuracy of Long_tailed_Jaeger :    0 %
# Accuracy of Pomarine_Jaeger :    6 %
# Accuracy of Blue_Jay :    0 %
# Accuracy of Florida_Jay :   31 %
# Accuracy of Green_Jay :    2 %
# Accuracy of Dark_eyed_Junco :    0 %
# Accuracy of Tropical_Kingbird :    8 %
# Accuracy of Gray_Kingbird :   31 %
# Accuracy of Belted_Kingfisher :    0 %
# Accuracy of Green_Kingfisher :    0 %
# Accuracy of Pied_Kingfisher :    0 %
# Accuracy of Ringed_Kingfisher :    0 %
# Accuracy of White_breasted_Kingfisher :    0 %
# Accuracy of Red_legged_Kittiwake :    4 %
# Accuracy of Horned_Lark :    0 %
# Accuracy of Pacific_Loon :    0 %
# Accuracy of Mallard :    0 %
# Accuracy of Western_Meadowlark :    0 %
# Accuracy of Hooded_Merganser :    0 %
# Accuracy of Red_breasted_Merganser :    0 %
# Accuracy of Mockingbird :    0 %
# Accuracy of Nighthawk :    0 %
# Accuracy of Clark_Nutcracker :    0 %
# Accuracy of White_breasted_Nuthatch :    0 %
# Accuracy of Baltimore_Oriole :    0 %
# Accuracy of Hooded_Oriole :    0 %
# Accuracy of Orchard_Oriole :   14 %
# Accuracy of Scott_Oriole :    0 %
# Accuracy of Ovenbird :    0 %
# Accuracy of Brown_Pelican :    0 %
# Accuracy of White_Pelican :    0 %
# Accuracy of Western_Wood_Pewee :    0 %
# Accuracy of Sayornis :    0 %
# Accuracy of American_Pipit :    0 %
# Accuracy of Whip_poor_Will :    0 %
# Accuracy of Horned_Puffin :   15 %
# Accuracy of Common_Raven :    3 %
# Accuracy of White_necked_Raven :    6 %
# Accuracy of American_Redstart :    0 %
# Accuracy of Geococcyx :    0 %
# Accuracy of Loggerhead_Shrike :    0 %
# Accuracy of Great_Grey_Shrike :    0 %
# Accuracy of Baird_Sparrow :   41 %
# Accuracy of Black_throated_Sparrow :    0 %
# Accuracy of Brewer_Sparrow :    0 %
# Accuracy of Chipping_Sparrow :    0 %
# Accuracy of Clay_colored_Sparrow :    0 %
# Accuracy of House_Sparrow :    0 %
# Accuracy of Field_Sparrow :    0 %
# Accuracy of Fox_Sparrow :    0 %
# Accuracy of Grasshopper_Sparrow :    0 %
# Accuracy of Harris_Sparrow :    0 %
# Accuracy of Henslow_Sparrow :    0 %
# Accuracy of Le_Conte_Sparrow :    2 %
# Accuracy of Lincoln_Sparrow :    0 %
# Accuracy of Nelson_Sharp_tailed_Sparrow :   21 %
# Accuracy of Savannah_Sparrow :    0 %
# Accuracy of Seaside_Sparrow :    0 %
# Accuracy of Song_Sparrow :    0 %
# Accuracy of Tree_Sparrow :    0 %
# Accuracy of Vesper_Sparrow :    2 %
# Accuracy of White_crowned_Sparrow :    0 %
# Accuracy of White_throated_Sparrow :    0 %
# Accuracy of Cape_Glossy_Starling :    5 %
# Accuracy of Bank_Swallow :    0 %
# Accuracy of Barn_Swallow :    0 %
# Accuracy of Cliff_Swallow :    0 %
# Accuracy of Tree_Swallow :    0 %
# Accuracy of Scarlet_Tanager :    0 %
# Accuracy of Summer_Tanager :    0 %
# Accuracy of Artic_Tern :    0 %
# Accuracy of Black_Tern :    0 %
# Accuracy of Caspian_Tern :    0 %
# Accuracy of Common_Tern :    0 %
# Accuracy of Elegant_Tern :    0 %
# Accuracy of Forsters_Tern :    0 %
# Accuracy of Least_Tern :    0 %
# Accuracy of Green_tailed_Towhee :    0 %
# Accuracy of Brown_Thrasher :    0 %
# Accuracy of Sage_Thrasher :    0 %
# Accuracy of Black_capped_Vireo :    3 %
# Accuracy of Blue_headed_Vireo :    0 %
# Accuracy of Philadelphia_Vireo :    0 %
# Accuracy of Red_eyed_Vireo :    0 %
# Accuracy of Warbling_Vireo :    0 %
# Accuracy of White_eyed_Vireo :    0 %
# Accuracy of Yellow_throated_Vireo :    0 %
# Accuracy of Bay_breasted_Warbler :    0 %
# Accuracy of Black_and_white_Warbler :    5 %
# Accuracy of Black_throated_Blue_Warbler :    0 %
# Accuracy of Blue_winged_Warbler :    0 %
# Accuracy of Canada_Warbler :    0 %
# Accuracy of Cape_May_Warbler :    0 %
# Accuracy of Cerulean_Warbler :    0 %
# Accuracy of Chestnut_sided_Warbler :    0 %
# Accuracy of Golden_winged_Warbler :    0 %
# Accuracy of Hooded_Warbler :    0 %
# Accuracy of Kentucky_Warbler :    6 %
# Accuracy of Magnolia_Warbler :    0 %
# Accuracy of Mourning_Warbler :    0 %
# Accuracy of Myrtle_Warbler :    0 %
# Accuracy of Nashville_Warbler :    0 %
# Accuracy of Orange_crowned_Warbler :    0 %
# Accuracy of Palm_Warbler :    0 %
# Accuracy of Pine_Warbler :    0 %
# Accuracy of Prairie_Warbler :    5 %
# Accuracy of Prothonotary_Warbler :   48 %
# Accuracy of Swainson_Warbler :    0 %
# Accuracy of Tennessee_Warbler :    0 %
# Accuracy of Wilson_Warbler :    0 %
# Accuracy of Worm_eating_Warbler :    0 %
# Accuracy of Yellow_Warbler :    0 %
# Accuracy of Northern_Waterthrush :    0 %
# Accuracy of Louisiana_Waterthrush :    0 %
# Accuracy of Bohemian_Waxwing :    0 %
# Accuracy of Cedar_Waxwing :    0 %
# Accuracy of American_Three_toed_Woodpecker :   17 %
# Accuracy of Pileated_Woodpecker :   51 %
# Accuracy of Red_bellied_Woodpecker :    0 %
# Accuracy of Red_cockaded_Woodpecker :    0 %
# Accuracy of Red_headed_Woodpecker :    0 %
# Accuracy of Downy_Woodpecker :    0 %
# Accuracy of Bewick_Wren :    0 %
# Accuracy of Cactus_Wren :    0 %
# Accuracy of Carolina_Wren :   21 %
# Accuracy of House_Wren :    0 %
# Accuracy of Marsh_Wren :    0 %
# Accuracy of Rock_Wren :    0 %
# Accuracy of Winter_Wren :   36 %
# Accuracy of Common_Yellowthroat :    0 %
